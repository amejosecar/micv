# %% [markdown]
# Américo José Carrillo Carrillo
# Bizkaia - España | LinkedIn: www.linkedin.com/in/amejosecar  | email: amejosecar@hotmail.com +34 615.660.174 Master/Lic. ADE orientado a la TIC - Bootcamp Ciencias del Dato (490 hrs)
# Actualmente cursando LABORLAN 2025: PROGRAMACIÓN WEB CON ESPECIALIZACIÓN EN IA Y PYTHON (510hrs)
#
# Soy un profesional con más de 10 años de experiencia en el sector IT de energía, petróleo y gas, y recientemente completé un Bootcamp de Ciencia de Datos de 490 horas, lo que me ha permitido fortalecer mis conocimientos y habilidades en tecnología. A lo largo de mi trayectoria, me he especializado en la gestión y coordinación de proyectos tecnológicos, planificando, supervisando y asegurando su ejecución eficiente. Trabajo en estrecha colaboración con diferentes áreas para alinear cada iniciativa con los objetivos del negocio y garantizar su implementación exitosa. Además, realizo un seguimiento constante del progreso de los proyectos, asegurándome de que se cumplan los plazos, los estándares de calidad y la correcta asignación de recursos.
# También me encargo de optimizar el uso de recursos humanos, técnicos y financieros, asegurando la eficiencia y efectividad en cada etapa. Ante cualquier incidencia, identifico riesgos y tomo acciones correctivas para minimizar su impacto y mantener el desarrollo del proyecto en marcha. La comunicación es clave en mi rol, por lo que mantengo informadas a todas las partes interesadas sobre avances, hitos y posibles ajustes en la planificación. Asimismo, gestiono la documentación de los proyectos, asegurando que esté organizada, actualizada y alineada con los requisitos técnicos y de calidad. Finalmente, analizo los resultados de cada proyecto para identificar oportunidades de mejora y optimizar procesos para futuras iniciativas.
#
# Professional Experience
# IT Project Manager - Gestor de proyectos - Analista funcional - Business Consultant - Analista del dato y especialista de Reporting
# •	Petrolera RN (CYPRUS) LIMITED	(2 años) Febrero 2020 – febrero 2022
# •	Petrolera RN - Rosneft	(8 años) Febrero 2014 – febrero 2020 Análisis funcional y asistente a la gerencia de operaciones y directores (stackeholders), asistencia en la gestión de proyectos (planificación, seguimiento plan anual de proyectos, multiproyectos, innovadores y de tecnologías actualizadas). Gestión de aplicaciones – software, gestión de requerimientos (capturar, analizar, priorizar), gestión de proveedores. Negociación avanzada y estratégicas. Miembro de la Unidad del Negocio, coordinación de acciones para garantizar la continuidad operativa del negocio, a través del control económico de los proyectos.	Gestión de documentación y de informes, de los datos y de reportes - Reporting (Consolidación, centralización y análisis del dato (información); desarrollo, optimización y mantenimiento de informes y presentaciones – dashboards), implementación de mejores prácticas en el diseño y desarrollo de soluciones orientado a establecer prioridades del negocio. Modelado de datos y ETL; para la mejora de la eficiencia operativa, coordinación con diferentes unidades y equipos del negocio para garantizar la continuidad operativa. Seguimiento preciso de directrices del coordinador del equipo, responsable en la ejecución de tareas asignadas. Comunicación efectiva, coaching organizacional, actitud de servicio y atención al cliente, trabajo en equipo de alto rendimiento. Visión y pensamiento estratégico del negocio.
# IT Project Manager - Gestor de proyectos - Analista functional - CAU | Lead of Specialized Applications and VIP
# •	TNK - British Petroleum (BP) (3 años) 2011 -	2014
# •	British Petroleum (BP) (6 años) 2005 –	2011
# •	PDVSA (8 años) 1996 -	2003
# Análisis funcional, gestión de requerimientos, gestión de proyectos, gestión de aplicaciones - software, gestión del dato, gestión de documentos, gestión de contenido, gestión de proveedores. Punto focal de IT, protocolo de test y pruebas funcionales de las aplicaciones. Interacción con usuarios CAU nivel 1,2,3. Conocimientos de herramientas de gestión de incidencias con remedy para manejo de ticketing. Conocimientos en administración de Directorio Activo, altas, bajas de usuarios, gestión de permisos y recursos. Gestión de usuario, soporte a usuarios de forma local y remota (telefónica y conexión remota) y soporte de aplicaciones en la integración con otros sistemas y plataformas, resolución de problemas, gestión de incidencias de varios niveles. Configuración de seguridad y permisos, monitorización y mantenimiento de aplicaciones. Gestión de conocimiento, implementación de mejores prácticas en el diseño y desarrollo de soluciones. elaboración de documentación técnica, elaboración de soluciones. Gestión de requerimientos, evaluación de solicitudes de cambio, coordinación de mejoras para la eficiencia operativa. Preparar los ordenadores e instalar software para nuevas incorporaciones o cambios de equipamiento. Mantener el inventario de la compañía y gestionar la activación y desactivación de servicios y dispositivos asignados. Formación y soporte a usuarios finales. Modelado de datos ETL de datos con SQL, desarrollo de aplicaciones a medida. Orientado al cliente, capacidad de trabajo en entornos colaborativos. Gestión del dato, reportes - Reporting, informes.
#
# Habilidades
# Habilidades desarrolladas: Asistente / Analista de Negocios, gestión de proyectos: Planificación, seguimiento e implementación de proyectos con metodología clásica y bajo metodologías Agile/Scrum, definición de alcance, objetivos y cronogramas, y gestión completa de proyectos desde la planificación hasta la fase post-cierre. Supervisión de contratos, monitoreo de KPIs y análisis de riesgos, participación activa en comités estratégicos y documentación detallada de proyectos y procesos. Además, optimización de procesos e implementación de metodologías de mejora continua. Gestión del Dato: Modelado de datos, extracción, transformación y carga del dato (ETL) con SQL, gestión y análisis de datos reales de producción, e integración de fuentes de datos externas. Suministro de información y reportes – Reporting basados en datos analizados, análisis de tendencias y garantía de la exactitud e integridad de los datos. Análisis de Datos y Reporting: Interpretación y análisis de datos complejos para decisiones informadas, diseño de informes adaptados a las necesidades del negocio, colaboración con departamentos para entender necesidades analíticas, identificación de tendencias y generación de insights. Diseño, desarrollo y mantenimiento de dashboards e informes, producción de reportes - Reporting claros y detallados para presentaciones, definición y monitoreo de KPIs, y elaboración de reportes - Reporting de seguimiento, evaluaciones y presentaciones de avances. Gestión Documental: Gestión de flujo de trabajo, Gestión del conocimiento, elaboración y mantenimiento de documentación técnica, diseño e implementación de soluciones documentales y mejores prácticas, y documentación de cambios, requerimientos y soluciones técnicas. Gestión de Proveedores: Negociación y supervisión de contratos con proveedores tecnológicos, gestión de incidencias y aseguramiento de la calidad en la entrega de servicios externos. Servicio al Cliente – Helpdesk (escalación N1, N2 y N3): Gestión de peticiones y soporte técnico a usuarios (local y remoto), resolución de incidencias en aplicaciones, sistemas y plataformas, capacitación y soporte técnico a usuarios finales, y administración de tickets en sistemas como Remedy, seguimiento y cierre de incidencias con proveedores (escalación N3). Liderazgo y Gestión de Talento: Coordinación de equipos y desarrollo de equipos de alto rendimiento, gestión del talento y coaching organizacional, implementación de nuevos modelos de organización, y capacitación y gestión del cambio en equipos. Especialista en TI: Integración de aplicaciones con sistemas y fuentes de datos, configuración de seguridad y permisos en entornos IT, monitorización y mantenimiento de aplicaciones críticas, y gestión de licencias y espacios de trabajo. Habilidades Interpersonales y Comunicación: Comunicación efectiva y habilidades interpersonales avanzadas, adaptabilidad a culturas e idiomas.
#
# Habilidades técnicas: Lenguajes de programación y scripting: Python, JavaScript, HTML5, CSS3 y PowerBuilder, React, Django, Flask, HTMX. Herramientas de visualización y análisis de datos: Power Query, Power Pivot (M), Power Bi, DAX, Pandas, Numpy, Ibis, Plotly, Matplotlib, Seaborn y Folium. Gestión y estructuración de datos: Estructuras de datos (JSON, CSV, Dataframe), obtención de datos (API, Webscrapping). Bases de datos: SQLite, Snowflake, SQL-Server, MS Access, Oracle, Aiven, PostgreSQL, MongoDB, DQL, SQL, Excel macros. Herramientas de desarrollo y control de versiones: Git + GitHub, Markdown. Herramientas y software Empresarial: Remedy, suite Microsoft 0365 (Word, Excel, PowerPoint, Project, Visio, Outlook, OneDrive), Microsoft Automate, Microsoft SharePoint, Documentum, PDF. Gestión de proyectos y metodologías: Gestión de proyectos, Scrum, Agile, planificación, gestión de KPIs, gestión de documental, trello. Herramientas colaborativas y de comunicación: Microsoft Teams, Zoom, Skype.
# Education
# Bootcamp Ciencias del Dato (490 hrs)	2024
# The Briged
# Scrum Master	2024
# European Scrum
# Coach organizacional internacional (ACSTH)	2016
# ANUV y MVL Consultores – ICF
# Master Of Science In Management. - Caracas, Venezuela
# Caribbean International University (CIU)	2014-2015
# Bachelor Of Science In Management. - Caracas, Venezuela	2012-2014
# Caribbean International University (CIU)
# Técnico superior en Informática. Caracas, Venezuela (FP Superior)	1992–1995
# Instituto Universitario de Tecnología Industrial «Rodolfo Loero Arismendi»
# Desarrollo profesional continuo (2025-2024): Power Automate, Microsoft Excel Macros-VBA, Bootcamp Ciencias del Dato (The Brigred – 490hrs), Análisis de datos con Excel: Power Query, Power Pivot y Power BI, Gestión ágil de proyectos con scrum; Big Data con Phyton; Business intelligence: Power query/Power Pivot/Power Bi; Excel avanzado; Procesamiento de datos con java; Desarrollo de Aplicaciones WEB; Scrum: gestión de proyectos con metodologías ágiles..… y con ganas de más.
# Conocimiento e intereses
# •	Idiomas: Inglés. (varios test me han calificado como A2)
# •	Intereses: Futbol, Artes Marciales (Karate/Aikido), aprendizaje continuo, ver series y películas y mi familia.
#
#
#
#
#
# EXPERIENCIA LABORAL
#
# PETROLERA RN (CYPRUS) LIMITED. CARACAS, VENEZUELA.                                        Febrero 2020 – febrero 2022
# Especialista de reporte de Operación y Producción de Petróleo
#
# PETROLERA RN (ROSNEFT DE VENEZUELA). CARACAS, VENEZUELA.                                 Febrero 2014 – febrero 2020
# Especialista de reporte de Operación y Producción de Petróleo
#
#
# Asistencia a la Dirección de producción y operaciones; análisis funcional para llevar a cabo el cumplimiento del plan de producción de petróleo y gas, y la continuidad del negocio. Gestión de proyectos y KPIs de producción y operación de petróleo y gas; identificación y análisis de oportunidades para mejorar la eficiencia operativa. Enlace con Oficina Corporativa de Moscú para reportes e informes de producción, informes de desempeño e informes de proyectos.
#
# Acompañar a las áreas operativas (PetroMonagas, PetroPerijá y Boquerón), para:
# •	Anticipar y entender la necesidad real de cada área
# •	Evaluar riesgos e identificar oportunidades de mejora en la eficiencia operativa
# •	Coordinar las intervenciones en conjunto con las distintas unidades para mejorar los procesos de producción, seguimiento, apoyo a la producción establecida en el plan anual y apoyo a la continuidad operativa.
#
# Miembro en el Comité de Finanzas en representación de las áreas operativas IJV (PetroMonagas, PetroPerijá y Boquerón) para realizar seguimiento el flujo de caja y garantizar la continuidad operativa del negocio y alcanzar el plan anual de la producción.
#
# Miembro en el Comité de proyectos en representación de las áreas operativas IJV (PetroMonagas, PetroPerijá y Boquerón) para realizar seguimiento a los procedimientos de contratación, para garantizar la continuidad operativa del negocio y alcanzar el plan anual de la producción.
#
# Miembro del centro de recolección de data real de producción de las áreas operativas IJV (PetroMonagas, PetroPerijá y Boquerón), para monitorear la producción diaria y así garantizar el cumplimiento de los planes de producción anual. Coordinar la generación y mantenimiento de los tableros de control de indicadores de operaciones y la identificación de la producción diferida para localizar las brechas que no permitieran lograr los planes de producción y establecer posibles soluciones que apunten al cumplimiento operativo o incremento de los planes anuales de producción
#
# Enlace con la Oficina Corporativa de Moscú con respecto a las áreas operativas (PetroMonagas, PetroPerijá y Boquerón), entregando reportes de producción, avances de los proyectos, evaluaciones y presentaciones de informes de producción y desempeño. Centro del dato de producción de crudo y gas para apoyar a las áreas del negocio.
#
# Logros obtenidos: Incremento de un 10% por año, de la producción de crudo sobre el valor estimado para lo que va en el año 2020-2021.
#
# Miembro de la brigada de 1ero auxilios y evacuación. (2020 hasta el 2022)
#
# Aplicaciones: Microsoft Office 2010, Access.
#
# TNK-Bp E&P. CARACAS, VENEZUELA.                                                                                     Julio 2011 – febrero 2014
# Lead of Specialized and Web App
#
# Coordinar aplicaciones petrotécnicas y la gerencia del dato.
# •	Coordinar la generación de reportes de producción con frecuencia diaria, semanal y mensual.
# •	Administrar servidor de licencias de las aplicaciones petrotécnicas´
# •	Actualizaciones, exportación e importación de ficheros petrotécnicos.
# •	Coordinar con proveedores petrotécnicos la solución de soporte de tercer nivel.
# •	Coordinar la gestión de apoyo de administradores de Base de Datos, de Servidores.
# •	Coordinar la implantación de Workstation y portátiles petrotécnicas.
# •	Coordinar requerimientos de usuarios y sus soluciones.
# •	Asesorar e implementar mejores prácticas para ambientes de trabajo.
#
# Aplicaciones petrotécnicas: Suite Schlumberger (Petrel, Eclipse, OFM, Techlog), Petroleum Experts IPM 7.5, Oracle Crystal Ball, VIP, CMG, RMS Roxar, PIE, Hamp-Russ.
#
# Logros obtenidos: Incremento de un 20% de la producción de crudo sobre el valor estimado para el cierre del ejercicio 2013.
#
# Coordinar aplicaciones web:
# •	Desarrollo en Share Point 2010.
# o	Toma de requisitos, desarrollo e implantar soluciones, Administrador de servidor .
# o	Área:
# 	Finanzas (Excel book1, Excel - reportes de gastos, Request COA, address book, órdenes de compra, actas de entregas), Impuestos (Reportes de Pagos de Impuestos).
# 	Recursos Humanos (certificación de trabajo/certificación de pago de bonos, tablero de vacaciones, políticas y procedimientos, reportes incidentes de proveedores).
# 	Presidencia: sistema de control de entrada y salida de comunicaciones corporativas.
# o	Intranet de TNK-BP – Venezuela, desarrollo local y mantenimiento.
#
#
# Aplicaciones: Microsoft Office 2010, Access, Infopath 2010, Share Point 2010, Sql-Server 2010).
#
# Líder de Proyecto de transición tras la venta de la empresa TNK-BP a Rosneft
# •	Coordinar el proceso de limpieza de los activos de IT (laptops, Desktop, Workstation e impresoras) y garantizar el nuevo ambiente operativo para las aplicaciones petrotécnicas y aplicaciones Web.
# •	Coordinar y garantizar la continuidad operativa de las aplicaciones petrotécnicas.
# •	Garantizar respaldo y eliminación de data de propiedad intelectual de TNK-BP Global en los diferentes servidores y ordenadores de usuarios finales.
# •	Soporte post-implantación de la nueva infraestructura petrotécnica y web.
# Logros obtenidos: Se aseguró la continuidad laboral para los empleados en el tiempo establecido (3 días)., sin desviación del plan establecido.
#
# Miembro de la brigada de 1ero auxilios y evacuación. (2011 hasta el 2014)
#
# BP E&P, Caracas - Venezuela                                                                                                            Julio 2005 – Junio 2011
# Lead of Specialized Applications and VIP (Contratado)
# Coordinar aplicaciones petrotécnicas y la gerencia del dato.
# •	Coordinar la generación de reportes de producción con frecuencia diaria, semanal y mensual.
# •	Administrar servidor de licencias de las aplicaciones petrotécnicas´
# •	Actualizaciones, exportación e importación de ficheros petrotécnicos.
# •	Coordinar con proveedores petrotécnicos la solución de soporte de tercer nivel.
# •	Coordinar la gestión de apoyo de requerimiento CAU 2º nivel.
# •	Coordinar la gestión de apoyo de administradores de Base de Datos, de Servidores.
# •	Coordinar la implantación de Workstation y portátiles petrotécnicas.
# •	Coordinar requerimientos de usuarios y sus soluciones.
# •	Asesorar e implementar mejores prácticas para ambientes de trabajo.
#
# Aplicaciones: Suite Landmark (Openworks), RM Roxar, Techlog, Petroleum Experts IPM 7.5, Oracle Crystal Ball, VIP, CMG, PIE, Hamp-Russ.
#
# Soporte para aplicaciones Ms Microsoft Excel- Excel (book1), Excel reporte de producción, Excel reporte de pago de nómina, Excel reporte de gastos.
#
# Documentum / SQL Oracle / Oracle / Windows Server
# •	Experticia
# o	Toma de requisitos
# o	Desarrollo de prototipo
# o	Desarrollo del modelo final.
# o	Migración de repositorio original a documentum.
# o	Puesta en real la solución final
# o	Soporte de 2º Nivel a usuarios finales de Documentum
# •	Desarrollo de soluciones
# o	RRHH: Desarrollo de la solución de documentación del journey del empleado
# o	Seguridad y Salud operacional: Desarrollo de solución para implementar la metodología de mejora de procesos (OMS) en las áreas operativas.
# o	Petrotécnico: Solución para para implementar carpeta de vida de los pozos
#
# •	Reconocimiento: por el excelente desempeño dentro del proyecto de reactivación de la plataforma Documentum y por implementación del modelo Documentum para soportar la metodología de mejora de procesos (OMS) sobre la plataforma Documentum.
#
# Coordinar soporte 2º Nivel y Soporte VIP
# •	Asesorar a usuarios en la canalización de requerimientos al grupo CAU 1º Nivel.
# •	Resolución de requerimientos 2º Nivel, cumplimientos de ANS.
# •	Logros obtenidos: 90% de la continuidad operativa de las aplicaciones técnicas, financieras y administrativas. Satisfacción de usuarios por encima de un 95% por casos cerrados en 2º nivel.
# •	Coordinación de respaldo (Backup) de servidores Petrotécnicos
# Aplicaciones: Microsoft Office 2010, Ms Microsoft Access, Outlook.
#
# Líder de Proyecto de transición tras la venta de la empresa BP a TNK-BP
# •	Coordinar el proceso de limpieza de los activos de IT (laptops, Desktop, Workstation e impresoras) y garantizar el nuevo ambiente operativo. (Ms Outlook, Ms Microsoft office, Aplicaciones petrotécnicas).
# •	Coordinar y garantizar la continuidad operativa de las aplicaciones petrotécnicas.
# •	Garantizar el traspaso de ficheros petrotécnicos a la empresa TNK-BP.
# •	Garantizar el traspaso de correos históricos en los ordenadores de los usuarios
# •	Garantizar respaldo y eliminación de data de propiedad intelectual de BP Global en los diferentes servidores y ordenadores de usuarios finales.
# •	Soporte post-implantación de la nueva infraestructura petrotécnica y web.
#
# Logros obtenidos: Se aseguró la continuidad laboral para los empleados en el tiempo establecido (3 días), con una desviación de apenas un 0,5% del plan establecido.
#
# Líder de proyecto de transición tras la entrega de campos petroleros de BP a PDVSA
# •	Coordinar el proceso de limpieza de los activos de IT (laptops, Desktop, Workstation e impresoras) y garantizar el nuevo ambiente operativo. (Aplicaciones petrotécnicas).
# •	Coordinar y garantizar la continuidad operativa de las aplicaciones petrotécnicas.
# •	Garantizar el traspaso de ficheros petrotécnicos a la empresa PDVSA.
# •	Garantizar respaldo y eliminación de data de propiedad intelectual de BP Global en los diferentes servidores y ordenadores de usuarios finales (Petrotécnicos).
# •	Garantizar la continuidad operativa de las aplicaciones petrotécnicas.
# •	Soporte post-implantación de la nueva infraestructura petrotécnica.
#
# Logros obtenidos: Se aseguró la continuidad laboral para los empleados en el tiempo establecido (30 días), con una desviación de apenas un 15% del plan establecido.
#
# Reconocimiento: Por el desempeño dentro del proyecto transferencia a empresas Mixtas PetroPerijá, Boquerón y PetroMonagas.
#
# PETROZUATA, PUERTO LA CRUZ, VENEZUELA                                                                                    ABRIL 2005–DIC 2006.
# ENGINEER DEVELOPER LEADER
# Desarrollo de soluciones de Documentum y SQL Oracle
# •	Toma de requisitos, desarrollo, migración e implantar soluciones.
# •	Petrotécnico: Solución para para implementar carpeta de vida de los pozos
#
# Aplicaciones: Documentum y SQL Oracle.
#
# PDVSA, CARACAS, VENEZUELA                                                                                                            AGOSTO 1995–DIC 2003.
# ANALISTA FUNCIONAL DE TECNOLOGÍA
# o	CAU de Aplicaciones – 1º nivel-año 2001–2003
# •	Analista de primer nivel con herramientas de control remoto, para aplicaciones especializadas -cliente/servidor y asociadas con actividades centrales de exploración, producción, comercio, suministro y Microsoft Office 97, Microsoft Office 2000, Microsoft Office XP, email Lotus Note.
# •	Gestión de incidencias o de requerimientos, escalamiento a áreas de experticias, seguimiento, consultas.
# •	Coordinación de conferencias y aprobación de documentación para nuevas versiones.
# •	Evaluación de solicitudes de cambio para liberar nuevas versiones o correcciones, asegurando el pleno cumplimiento de los procesos y estándares.
#
# Aplicaciones: Microsoft Office 97, Microsoft Office 2000, Microsoft Office XP, email Lotus Note, html, PL/SQL Oracle.
#
# o	CAU de Aplicaciones - 2do nivel-año 2000–2001
# •	Aplicación SIRET
# •	Gestión de fallas/consultas escaladas.
# •	Analizar, desarrollar e implementar fallas, mejoras y nuevos requerimientos.
# •	Administración de versiones.
# •	Instalación/actualización de la aplicación en cada usuario de negocio requerido y salas de adiestramiento a usuarios finales.
#
# Aplicaciones: PowerBuilder, PL/SQL Oracle.
#
# o	Desarrollo de aplicaciones a la medida.
# •	Siret (Sistema de Reporte de tiempo), sistema para las guardias de operadores de petróleo y gas, para las diferentes filiales de Petróleos de Venezuela (PDVSA)-año 1998–1999
# •	Sistema de control de carga buque, de petróleo y gas.-año 1995. Corpoven, s.a. caracas-filial de Petróleos de Venezuela (PDVSA)
#
# Aplicaciones: PowerBuilder, PL/SQL Oracle
#
# o	Manejo de documento electrónicos
# •	Instalación/actualización de soluciones de manejo de documento electrónicas, M&B Dossier.
# •	Manejo de expedientes de la gerencia de PCP (Protección y Control de Pérdidas), año 1997, Maraven/Pequiven, Caracas - filial de Petróleos de Venezuela (PDVSA)
# •	Manejo de puntos de cuentas de la junta directiva, año 1996. Maraven–caracas-filial de Petróleos de Venezuela (PDVSA)
#
# Aplicaciones: Visual Basic, PL/SQL Oracle, M&B Dossier.
#
#
# FORMACIÓN
# Master Of Science In Management. Caribbean International University (CIU) - Caracas, Venezuela (2014-2015)
# Bachelor Of Science In Management. Caribbean International University (CIU) - Caracas, Venezuela (2012-2014)
# Técnico superior en Informática. Instituto Universitario de Tecnología Industrial «Rodolfo Loero Arismendi», Caracas, Venezuela (1992–1995)
#
# Scrum/Scrum Master, En progreso la certificación, European Scrum. (2023)
#
#
# CURSOS RECIBIDOS
# Gerenciales: Planificación estratégica (2015), Negociando con el enemigo (2006), Reuniones Efectivas (2004). Gerencia del cambio (2004), Gerencia de proyectos (2003), Planificación Estratégica (2003), Formación de Facilitadores (Ccs, Vzla, Febrero 2002), SREM (Manejo de requerimientos CMM) Mayo 2001, SCMPVCS Junio 2001, Certificado como Facilitador (Atlanta-Usa, Abril2001), Liderazgo para No Gerentes (Abril 2001), Liderazgo y productividad Empresarial (Marzo 2001), Liderazgo en Tiempos Caóticos (Abril 2000), Equipos de altos rendimientos(Febrero 2000); Desarrollo de habilidades Gerenciales (junio-2000), The art of business coaching (1996); Competencias Conversacionales (basado en la Ontología del Lenguaje) (1996), Metodología del proceso (1996).
#
# Técnicos: Accelerated Training for Landmark (2010), Administración de Openworks (2008), A+Plus de Microsoft Agosto-2002, Accelerated Training for Microsoft Windows XP May-2002, Accelerated Training for Microsoft Windows 2000 Marzo-2002, ARS (Noviembre-2000), PowerBuilder ver. 6.5(Octubre-2000), Coaching Empresarial (Ocubre-2000), Fundamentos Adaptive Server Sybase (Herramientas de Manejador de BD Sybases Ver.6.0) (junio-2000), Conceptos, facilidades y Herramientas  M&B Dossier Ver 3.0 (Manejador de Documento Electrónico); Accelerated Training for Microsoft Windows NT 4.0; Administración de Oracle Ver 7.x (Conceptos y facilidades); Conceptos y facilidades  de Oracle Ver 7.x, Metodología del Workflow en Competencias Conversacionales; DB2: Conceptos, facilidades, programación; PowerBuilder (nivel I); Sql; Filosofía Cliente/Servidor; Mantenimiento y Prevención de Microcomputadores.
#
# EXPERIENCIA EXTRACURRICULAR
# Miembro de la Cámara Júnior Cámara Júnior de Venezuela y de la Internacional (JCI) desde 1999 liderando diversos proyectos sociales de alto impacto y ocupando cargos en el ámbito local.  Facilitador de Aprendizaje.  Secretario 2001 Capítulo Caracas.  Presidente Local 2002 Capítulo Caracas.  Inmediato Presidente Anterior 2003 Capítulo Caracas. Líder del grupo Interés 2008 de la Gran Caracas.
